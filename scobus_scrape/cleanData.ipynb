# %%
import pandas as pd

# %%
df = pd.read_csv('10000.csv')
df
# Out:
#                                                 Authors  \
# 0     Roztocki N.; Strzelczyk W.; Roland Weistroffer H.
# 1                                             Okan A.A.
# 2                   Susanto T.D.; Goodwin R.; Calder P.
# 3     Quiralte J.; Llanes E.; Barral P.; Arias De Sa...
# 4                                  Dave C.G.; Shah R.D.
# ...                                                 ...
# 9995  Mayfield J.M.; Hitefield N.L.; Czajewski I.; V...
# 9996                     Jiang L.; Gu H.; Xu X.; Yan X.
# 9997  Kimura H.; Ishihara T.; Ishida M.; Hirabayashi...
# 9998                  Kundu M.; Gucchait A.; Misra A.K.
# 9999  Pedersen N.B.; Wang S.; Narimatsu Y.; Yang Z.;...
#
#                                       Author full names  \
# 0     Roztocki, Narcyz (6602215933); Strzelczyk, Woj...
# 1                        Okan, Aylin Akca (57133107700)
# 2     Susanto, Tony Dwi (22986633400); Goodwin, Robe...
# 3     Quiralte, J. (7003929627); Llanes, E. (2346995...
# 4     Dave, Chaitanya G. (7005281656); Shah, Rina D....
# ...                                                 ...
# 9995  Mayfield, Johnathan M. (58474792600); Hitefiel...
# 9996  Jiang, Lingchao (26321106000); Gu, Huizi (2632...
# 9997  Kimura, Hideto (35272192000); Ishihara, Tomoe ...
# 9998  Kundu, Monalisa (57209833511); Gucchait, Arin ...
# 9999  Pedersen, Nis Borbye (16417603300); Wang, Shen...
#
#                                            Author(s) ID  \
# 0                  6602215933; 57208127997; 57224766959
# 1                                           57133107700
# 2                  22986633400; 36138575100; 8875040200
# 3     7003929627; 23469958600; 58321244900; 65079424...
# 4                                7005281656; 7403034449
# ...                                                 ...
# 9995  58474792600; 57217856563; 57474346900; 5811240...
# 9996  26321106000; 26321101500; 56168045100; 5628707...
# 9997  35272192000; 56003412800; 59152796800; 5720734...
# 9998              57209833511; 57191224686; 55664860300
# 9999  16417603300; 57659010600; 56237632200; 5617138...
#
#                                                   Title  Year  \
# 0            E-democracy and Socio-economic Development  2022
# 1     Exploring the Landscape of e-Government Maturi...  2024
# 2           A six-level model of SMS-based e-government  2008
# 3     Ole e 2 and Ole e 10: New clinical aspects and...  2005
# 4     Annellation of triazole and tetrazole systems ...  2002
# ...                                                 ...   ...
# 9995  O-GlcNAc transferase congenital disorder of gl...  2024
# 9996  Selective hydrogenation of o-chloronitrobenzen...  2009
# 9997  Efficient and safe extraction of an antioxidan...  2024
# 9998  Convergent synthesis of a pentasaccharide corr...  2020
# 9999  Low density lipoprotein receptor class A repea...  2014
#
#                                            Source title Volume Issue Art. No.  \
# 0     28th Americas Conference on Information System...    NaN   NaN      NaN
# 1             Digital Government: Research and Practice      5     2       12
# 2     Proceedings of 4th International Conference on...    NaN   NaN      NaN
# 3     Allergy: European Journal of Allergy and Clini...     60     3      NaN
# 4                                             Molecules      7     7      NaN
# ...                                                 ...    ...   ...      ...
# 9995                    Journal of Biological Chemistry    300     9   107599
# 9996         Journal of Molecular Catalysis A: Chemical    310   1-2      NaN
# 9997               Food Science and Technology Research     30     3      NaN
# 9998                                        Tetrahedron     76     8   130952
# 9999                    Journal of Biological Chemistry    289    25      NaN
#
#      Page start  ...             ISBN  CODEN   PubMed ID  \
# 0           NaN  ...  978-195820000-1    NaN         NaN
# 1           NaN  ...              NaN    NaN         NaN
# 2           423  ...  978-190663820-7    NaN         NaN
# 3           360  ...              NaN  LLRGD  15679723.0
# 4           554  ...              NaN  MOLEF         NaN
# ...         ...  ...              ...    ...         ...
# 9995        NaN  ...              NaN  JBCHA  39059494.0
# 9996        144  ...              NaN  JMCCF         NaN
# 9997        313  ...              NaN    NaN         NaN
# 9998        NaN  ...              NaN  TETRA         NaN
# 9999      17312  ...              NaN  JBCHA  24798328.0
#
#      Language of Original Document                Abbreviated Source Title  \
# 0                          English             Am. Conf. Inf. Syst., AMCIS
# 1                          English                 Digit. Gov. Res. Pract.
# 2                          English           Proc. Int. Conf. e-Gov., ICEG
# 3                          English  Allergy Eur. J. Allergy Clin. Immunol.
# 4                          English                               Molecules
# ...                            ...                                     ...
# 9995                       English                          J. Biol. Chem.
# 9996                       English                  J. Mol. Catal. A Chem.
# 9997                       English                 Food Sci. Technol. Res.
# 9998                       English                             Tetrahedron
# 9999                       English                          J. Biol. Chem.
#
#          Document Type Publication Stage  \
# 0     Conference paper             Final
# 1              Article             Final
# 2     Conference paper             Final
# 3              Article             Final
# 4              Article             Final
# ...                ...               ...
# 9995            Review             Final
# 9996           Article             Final
# 9997           Article             Final
# 9998           Article             Final
# 9999           Article             Final
#
#                                             Open Access  Source  \
# 0                                                   NaN  Scopus
# 1              All Open Access; Hybrid Gold Open Access  Scopus
# 2                                                   NaN  Scopus
# 3                                                   NaN  Scopus
# 4                     All Open Access; Gold Open Access  Scopus
# ...                                                 ...     ...
# 9995  All Open Access; Gold Open Access; Green Open ...  Scopus
# 9996                                                NaN  Scopus
# 9997                                                NaN  Scopus
# 9998                                                NaN  Scopus
# 9999                 All Open Access; Green Open Access  Scopus
#
#                      EID
# 0     2-s2.0-85192549644
# 1     2-s2.0-85196908371
# 2     2-s2.0-84962778132
# 3     2-s2.0-20044374857
# 4      2-s2.0-3242806698
# ...                  ...
# 9995  2-s2.0-85201393669
# 9996  2-s2.0-67849090368
# 9997  2-s2.0-85194932933
# 9998  2-s2.0-85078076685
# 9999  2-s2.0-84903480472
#
# [10000 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Authors                        9992 non-null   object
#  1   Author full names              9992 non-null   object
#  2   Author(s) ID                   9992 non-null   object
#  3   Title                          10000 non-null  object
#  4   Year                           10000 non-null  int64
#  5   Source title                   9998 non-null   object
#  6   Volume                         8591 non-null   object
#  7   Issue                          6529 non-null   object
#  8   Art. No.                       2054 non-null   object
#  9   Page start                     8206 non-null   object
#  10  Page end                       8187 non-null   object
#  11  Page count                     8176 non-null   float64
#  12  Cited by                       9999 non-null   float64
#  13  DOI                            8939 non-null   object
#  14  Link                           10000 non-null  object
#  15  Affiliations                   9935 non-null   object
#  16  Authors with affiliations      9935 non-null   object
#  17  Abstract                       10000 non-null  object
#  18  Author Keywords                8790 non-null   object
#  19  Index Keywords                 9249 non-null   object
#  20  Molecular Sequence Numbers     226 non-null    object
#  21  Chemicals/CAS                  4772 non-null   object
#  22  Tradenames                     707 non-null    object
#  23  Manufacturers                  455 non-null    object
#  24  Funding Details                4359 non-null   object
#  25  Funding Texts                  3844 non-null   object
#  26  References                     9747 non-null   object
#  27  Correspondence Address         6898 non-null   object
#  28  Editors                        613 non-null    object
#  29  Publisher                      6004 non-null   object
#  30  Sponsors                       780 non-null    object
#  31  Conference name                2047 non-null   object
#  32  Conference date                2045 non-null   object
#  33  Conference location            2034 non-null   object
#  34  Conference code                2039 non-null   float64
#  35  ISSN                           8591 non-null   object
#  36  ISBN                           1933 non-null   object
#  37  CODEN                          5289 non-null   object
#  38  PubMed ID                      4576 non-null   float64
#  39  Language of Original Document  10000 non-null  object
#  40  Abbreviated Source Title       9985 non-null   object
#  41  Document Type                  10000 non-null  object
#  42  Publication Stage              10000 non-null  object
#  43  Open Access                    2772 non-null   object
#  44  Source                         10000 non-null  object
#  45  EID                            10000 non-null  object
# dtypes: float64(4), int64(1), object(41)
# memory usage: 3.5+ MB

# %%
df['Author Keywords'] = df['Author Keywords'].str.replace(';', ',', regex=False)

# %%
import pycountry
import pandas as pd

# ฟังก์ชันเพื่อดึงชื่อประเทศจากข้อความ
def extract_countries_pycountry(affiliations):
    if pd.isna(affiliations):  # ตรวจสอบว่าเป็น NaN หรือไม่
        return None
    
    # สร้างลิสต์ของประเทศทั้งหมดจาก pycountry
    countries = [country.name for country in pycountry.countries]
    
    # ใช้ Regular Expression เพื่อตรวจหาชื่อประเทศในข้อความ
    found_countries = [country for country in countries if country in affiliations]
    
    return ', '.join(found_countries) if found_countries else None

# ใช้ฟังก์ชัน extract_countries_pycountry กับคอลัมน์ 'Authors with affiliations'
df['Authors Country'] = df['Authors with affiliations'].apply(extract_countries_pycountry)

# %%
df[['Title','Source title','Cited by','Authors Country','Author Keywords', 'Year']].to_csv('10000_filtered.csv', index=False)
